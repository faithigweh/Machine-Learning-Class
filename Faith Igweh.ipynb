# %%
# !git clone https://github.com/faithigweh/Machine-Learning-Class.git
# !cd Machine-Learning-Class
# Out:
# Cloning into 'Machine-Learning-Class'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 12), reused 37 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 7.81 MiB | 24.08 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# Added a Jupyter notebook with a simple matplotlib plot.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# !mv 'Faith Igweh.ipynb' 'Machine-Learning-Class/Faith Igweh.ipynb'
# Out:
# mv: cannot stat 'Faith Igweh.ipynb': No such file or directory

# %%
# %%bash
# cd Machine-Learning-Class
# git config --global user.email "you@example.com" # REPLACE WITH YOUR EMAIL
# git config --global user.name "Your Name"      # REPLACE WITH YOUR NAME
# git add "Faith Igweh.ipynb"
# git commit -m "Add Faith Igweh notebook with sample plot"
# git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: pathspec 'Faith Igweh.ipynb' did not match any files
# fatal: could not read Username for 'https://github.com': No such device or address
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-3252419157.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd Machine-Learning-Class\ngit config --global user.email "you@example.com" # REPLACE WITH YOUR EMAIL\ngit config --global user.name "Your Name"      # REPLACE WITH YOUR NAME\ngit add "Faith Igweh.ipynb"\ngit commit -m "Add Faith Igweh notebook with sample plot"\ngit push origin main\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# ...

# %%
# Author: Faith Igweh
# Simple Machine Learning Example: Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# Create sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 4, 5, 4, 6])

# %%
# Train model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predictions
X_line = np.linspace(1, 5, 100).reshape(-1, 1)
y_pred = model.predict(X_line)

# %%
# Plot
plt.scatter(X, y, label="Actual Data")
plt.plot(X_line, y_pred, label="Regression Line")
plt.title("Linear Regression Example — Faith Igweh")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
